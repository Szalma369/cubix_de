# %%
import json
import os
import pandas as pd
import requests
from datetime import datetime
from dateutil.relativedelta import relativedelta

# %%
current_datetime = datetime.now() - relativedelta(months=8)
formatted_datetime = current_datetime.strftime('%Y-%m-%d')

url = f"https://data.cityofchicago.org/resource/wrvz-psew.json?$where=trip_start_timestamp >= '{formatted_datetime}T00:00:00' AND trip_start_timestamp <= '{formatted_datetime}T23:59:59'&$limit=30000"

headers = {'X-App-Token': os.environ.get('CHICAGO_API_TOKEN')}

response = requests.get(url, headers)

data = response.json()

# %%
data
# Out:
# [{'trip_id': 'c499eb134905e5bfa61e8f5a6c6cbc6be89574da',
#   'taxi_id': '78893d83a12762723e5a8ef770b3fb541e9b2cd8d4316d708a441760143a4ef1e313205a8801abec9e7a152b970f673d3f9b990c228de3a6499b933d7e9aedc9',
#   'trip_start_timestamp': '2023-11-27T23:45:00.000',
#   'trip_end_timestamp': '2023-11-28T00:00:00.000',
#   'trip_seconds': '900',
#   'trip_miles': '11.9',
#   'pickup_community_area': '7',
#   'dropoff_community_area': '69',
#   'fare': '30',
#   'tips': '0',
#   'tolls': '0',
#   'extras': '0',
#   'trip_total': '30',
#   'payment_type': 'Unknown',
#   'company': 'Choice Taxi Association',
#   'pickup_centroid_latitude': '41.922686284',
#   'pickup_centroid_longitude': '-87.649488729',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6494887289, 41.9226862843]},
#   'dropoff_centroid_latitude': '41.763246799',
#   'dropoff_centroid_longitude': '-87.616134111',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6161341112, 41.7632467988]}},
#  {'trip_id': 'bdbedbbb45bb3c45665242cbf7e6c3f420a87522',
#   'taxi_id': 'ce8e5531edf9255d9ecb2f930e320f9c1c83229e43744564103589a4cf339190c4c17ba66439c436305e3ebf2447ef2d418b2601edc83b81c08abdce5cd20334',
#   'trip_start_timestamp': '2023-11-27T23:45:00.000',
#   'trip_end_timestamp': '2023-11-27T23:45:00.000',
#   'trip_seconds': '38',
#   'trip_miles': '0.07',
#   'pickup_community_area': '24',
#   'dropoff_community_area': '24',
#   'fare': '3.5',
#   'tips': '0',
#   'tolls': '0',
#   'extras': '0',
#   'trip_total': '3.5',
#   'payment_type': 'Cash',
#   'company': 'Blue Ribbon Taxi Association',
#   'pickup_centroid_latitude': '41.901206994',
#   'pickup_centroid_longitude': '-87.676355989',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6763559892, 41.9012069941]},
#   'dropoff_centroid_latitude': '41.901206994',
#   'dropoff_centroid_longitude': '-87.676355989',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6763559892, 41.9012069941]}},
#  {'trip_id': 'bb29e0e0b72b8d393a5d03a5a14307992bfb8a00',
#   'taxi_id': '1d25c733bf526c55bcf3db1fd3856ba10b1064bd98ffce6ffb191faf6b5e21b6fca9c1f6302ad84ca65a1e56e28ebc9b3f05474764aac1007f0c23097e72b770',
#   'trip_start_timestamp': '2023-11-27T23:45:00.000',
#   'trip_end_timestamp': '2023-11-28T00:15:00.000',
#   'trip_seconds': '1680',
#   'trip_miles': '17.1',
#   'pickup_community_area': '56',
#   'dropoff_community_area': '6',
#   'fare': '42.75',
#   'tips': '9.65',
#   'tolls': '0',
#   'extras': '5',
#   'trip_total': '57.4',
#   'payment_type': 'Credit Card',
#   'company': 'Taxi Affiliation Services',
#   'pickup_centroid_latitude': '41.79259236',
#   'pickup_centroid_longitude': '-87.769615453',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.7696154528, 41.7925923603]},
#   'dropoff_centroid_latitude': '41.944226601',
#   'dropoff_centroid_longitude': '-87.655998182',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6559981815, 41.9442266014]}},
#  {'trip_id': 'b92691c61b414833d1a27a777a4eaa1d009ae20b',
#   'taxi_id': '48c0b5669ed50a0dcd8bf0e69fd99bb2669cb027ec06c0b76f9781a5497dcb8cb04b1d3106e61447749bfbb5b6547bc82fc3e94ce2ea87b154d3f53ad364be98',
#   'trip_start_timestamp': '2023-11-27T23:45:00.000',
#   'trip_end_timestamp': '2023-11-28T00:00:00.000',
#   'trip_seconds': '1057',
#   'trip_miles': '12.99',
#   'pickup_community_area': '28',
#   'dropoff_community_area': '71',
#   'fare': '33',
#   'tips': '0',
#   'tolls': '0',
#   'extras': '0',
#   'trip_total': '33',
#   'payment_type': 'Prcard',
#   'company': 'Flash Cab',
#   'pickup_centroid_latitude': '41.874005383',
#   'pickup_centroid_longitude': '-87.66351755',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6635175498, 41.874005383]},
#   'dropoff_centroid_latitude': '41.744205146',
#   'dropoff_centroid_longitude': '-87.656305986',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6563059862, 41.7442051463]}},
#  {'trip_id': 'b7c68bccd2e303c186820d13a50b55af472e4f71',
#   'taxi_id': '91a3888b4ec970ca2e5533c2736f85cfbaa0df79dcb5ab3e38538d68338df7ff4db7afd967e2734b879ad8dd35386d7a6568f5d2a6e2a9e303f3fcc10bfe5002',
#   'trip_start_timestamp': '2023-11-27T23:45:00.000',
#   'trip_end_timestamp': '2023-11-27T23:45:00.000',
#   'trip_seconds': '8',
#   'trip_miles': '0',
#   'fare': '65',
#   'tips': '9.82',
#   'tolls': '0',
#   'extras': '0',
#   'trip_total': '75.32',
#   'payment_type': 'Credit Card',
#   'company': '5 Star Taxi'},
#  {'trip_id': 'b9608d48fe2f0ad13013fbcc4b52a604e04f169f',
#   'taxi_id': 'c0d525ee45b1b77f1fcc69c7c56ff91661795d15482cc46a75ca8164ea25736a32169b1ba73fb5eee3ee98e629942c90ed23a5998f29bfe050afd3a08608a9a9',
#   'trip_start_timestamp': '2023-11-27T23:45:00.000',
#   'trip_end_timestamp': '2023-11-27T23:45:00.000',
#   'trip_seconds': '120',
#   'trip_miles': '0',
#   'pickup_community_area': '33',
#   'dropoff_community_area': '33',
#   'fare': '4',
#   'tips': '3',
#   'tolls': '0',
#   'extras': '0',
#   'trip_total': '7',
#   'payment_type': 'Credit Card',
#   'company': 'Taxi Affiliation Services',
#   'pickup_centroid_latitude': '41.857183858',
#   'pickup_centroid_longitude': '-87.620334624',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6203346241, 41.8571838585]},
#   'dropoff_centroid_latitude': '41.857183858',
#   'dropoff_centroid_longitude': '-87.620334624',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6203346241, 41.8571838585]}},
#  {'trip_id': 'b1df07de8af7a14fcadd369f2c77e7800c4d0f15',
#   'taxi_id': '158bdb99c0944908e89681ab608203e360f6e359ad4d94ec66617bb6bbb09f1ba7472a0a7d43a8ef444c7218eba2ee8fe5ddab92691f52663915dabe84a03236',
#   'trip_start_timestamp': '2023-11-27T23:45:00.000',
#   'trip_end_timestamp': '2023-11-28T00:00:00.000',
#   'trip_seconds': '350',
#   'trip_miles': '1.06',
#   'pickup_community_area': '32',
#   'dropoff_community_area': '32',
#   'fare': '6.5',
#   'tips': '3',
#   'tolls': '0',
#   'extras': '3.5',
#   'trip_total': '13.5',
#   'payment_type': 'Credit Card',
#   'company': 'Flash Cab',
#   'pickup_centroid_latitude': '41.878865584',
#   'pickup_centroid_longitude': '-87.625192142',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6251921424, 41.8788655841]},
#   'dropoff_centroid_latitude': '41.878865584',
#   'dropoff_centroid_longitude': '-87.625192142',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6251921424, 41.8788655841]}},
#  {'trip_id': 'b05e61cf8a96d25f00af7831bb53935189f284b3',
#   'taxi_id': '0ee86e2a204cc2224e9ff2494686ee474cce6aba093a1b9eb96b84fb0210d351254024e4ce9c9304e90372c6899ed1d35e8dce702882ba12d72ca651de70ad16',
#   'trip_start_timestamp': '2023-11-27T23:45:00.000',
#   'trip_end_timestamp': '2023-11-28T00:45:00.000',
#   'trip_seconds': '3274',
#   'trip_miles': '14.89',
#   'pickup_community_area': '76',
#   'dropoff_community_area': '1',
#   'fare': '41',
#   'tips': '9.3',
#   'tolls': '0',
#   'extras': '5',
#   'trip_total': '55.8',
#   'payment_type': 'Credit Card',
#   'company': 'Sun Taxi',
#   'pickup_centroid_latitude': '41.980264315',
#   'pickup_centroid_longitude': '-87.913624596',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.913624596, 41.9802643146]},
#   'dropoff_centroid_latitude': '42.009622881',
#   'dropoff_centroid_longitude': '-87.670166857',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6701668569, 42.0096228806]}},
#  {'trip_id': 'ac2fa5c734257b92c0d530a85a2661573cb40a17',
#   'taxi_id': 'd4e172502a18df80190c19176a06c0d9344f71abdbe521e964ad99caae1c73860f3f1f7cc96e1dcac410fbe9aba385af639ef03c028b0453429bbfb67e78010b',
#   'trip_start_timestamp': '2023-11-27T23:45:00.000',
#   'trip_end_timestamp': '2023-11-28T00:00:00.000',
#   'trip_seconds': '529',
#   'trip_miles': '2.08',
#   'pickup_community_area': '8',
#   'dropoff_community_area': '32',
#   'fare': '8.75',
#   'tips': '2',
#   'tolls': '0',
#   'extras': '1',
#   'trip_total': '12.25',
#   'payment_type': 'Credit Card',
#   'company': 'Globe Taxi',
#   'pickup_centroid_latitude': '41.899602111',
#   'pickup_centroid_longitude': '-87.633308037',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6333080367, 41.899602111]},
#   'dropoff_centroid_latitude': '41.878865584',
#   'dropoff_centroid_longitude': '-87.625192142',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6251921424, 41.8788655841]}},
#  {'trip_id': 'acd1ecb62c0582ad08877ccafe4fad0e4a22dab3',
#   'taxi_id': 'c54481366d44d8c3011e54e798279f735ed2b51d200a76f81e6fd2f763f5e69d27da4d63c03a7186e16a5ecfda77c50ffc566372fa1a65d78ee5b3b37137e934',
#   'trip_start_timestamp': '2023-11-27T23:45:00.000',
#   'trip_end_timestamp': '2023-11-28T00:00:00.000',
#   'trip_seconds': '1317',
#   'trip_miles': '17.13',
#   'pickup_community_area': '76',
#   'dropoff_community_area': '69',
#   'fare': '78.99',
#   'tips': '0',
#   'tolls': '0',
#   'extras': '0',
#   'trip_total': '78.99',
#   'payment_type': 'Cash',
#   'company': 'Flash Cab',
#   'pickup_centroid_latitude': '41.980264315',
#   'pickup_centroid_longitude': '-87.913624596',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.913624596, 41.9802643146]},
#   'dropoff_centroid_latitude': '41.763246799',
#   'dropoff_centroid_longitude': '-87.616134111',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6161341112, 41.7632467988]}},
#  {'trip_id': 'a139cd898709c066d6373f9964d07754a5e044fc',
#   'taxi_id': '42bfc19863617733aaa5ef96de670e3307690921a42d3df9e13ff7a35fa621088d7656cf297d3bb44306fa4ebc03bc631afc3c050b0562dea4b0b833e85818d2',
#   'trip_start_timestamp': '2023-11-27T23:45:00.000',
#   'trip_end_timestamp': '2023-11-28T00:00:00.000',
#   'trip_seconds': '285',
#   'trip_miles': '0.86',
#   'pickup_community_area': '8',
#   'dropoff_community_area': '8',
#   'fare': '5.5',
#   'tips': '0',
#   'tolls': '0',
#   'extras': '0',
#   'trip_total': '5.5',
#   'payment_type': 'Cash',
#   'company': 'Sun Taxi',
#   'pickup_centroid_latitude': '41.899602111',
#   'pickup_centroid_longitude': '-87.633308037',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6333080367, 41.899602111]},
#   'dropoff_centroid_latitude': '41.899602111',
#   'dropoff_centroid_longitude': '-87.633308037',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6333080367, 41.899602111]}},
#  {'trip_id': '98597dc625d3b95e9f994cf432eead9dacda4115',
#   'taxi_id': '5f9b8ebe05b8a28245cdc7b2c203aa8997bd86c7d87b05ced10faba715b760bbc484f3cb5f219abad87a2077054c1aeb1fcaacf348d9c9a60a82b0cacf67d00b',
#   'trip_start_timestamp': '2023-11-27T23:45:00.000',
#   'trip_end_timestamp': '2023-11-28T00:00:00.000',
#   'trip_seconds': '1173',
#   'trip_miles': '15.31',
#   'pickup_community_area': '76',
#   'dropoff_community_area': '22',
#   'fare': '38',
#   'tips': '8.7',
#   'tolls': '0',
#   'extras': '5',
#   'trip_total': '52.2',
#   'payment_type': 'Credit Card',
#   'company': '5 Star Taxi',
#   'pickup_centroid_latitude': '41.980264315',
#   'pickup_centroid_longitude': '-87.913624596',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.913624596, 41.9802643146]},
#   'dropoff_centroid_latitude': '41.92276062',
#   'dropoff_centroid_longitude': '-87.699155343',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6991553432, 41.9227606205]}},
#  {'trip_id': '95f38b0cc1b980bdfc7ab8bce3763b4737ea25ed',
#   'taxi_id': 'fe887a3007c0d8a3c0742efd766f5e589a312a921163262ebb685c9ba5a60f485465c6bac635a6c5245aeb228a0f01e2a3a33b4373b852a36f5b1055b4c2e597',
#   'trip_start_timestamp': '2023-11-27T23:45:00.000',
#   'trip_end_timestamp': '2023-11-28T00:15:00.000',
#   'trip_seconds': '1574',
#   'trip_miles': '16.25',
#   'pickup_community_area': '76',
#   'dropoff_community_area': '7',
#   'fare': '40.25',
#   'tips': '6.71',
#   'tolls': '0',
#   'extras': '4',
#   'trip_total': '51.46',
#   'payment_type': 'Credit Card',
#   'company': 'Star North Taxi Management Llc',
#   'pickup_centroid_latitude': '41.980264315',
#   'pickup_centroid_longitude': '-87.913624596',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.913624596, 41.9802643146]},
#   'dropoff_centroid_latitude': '41.922686284',
#   'dropoff_centroid_longitude': '-87.649488729',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6494887289, 41.9226862843]}},
#  {'trip_id': '919ed9ed82d3485560cd0a79e15d0efd2b032848',
#   'taxi_id': 'f705c825446b6687d3b45d5bb04a7a29720306923943f35ba050b6b5234e5dd564b074ace9b2e6c4c91c3dc09866a05908bed9d7f027d4f34f318274d5264b65',
#   'trip_start_timestamp': '2023-11-27T23:45:00.000',
#   'trip_end_timestamp': '2023-11-28T00:00:00.000',
#   'trip_seconds': '540',
#   'trip_miles': '0',
#   'pickup_community_area': '8',
#   'dropoff_community_area': '32',
#   'fare': '8.5',
#   'tips': '0',
#   'tolls': '0',
#   'extras': '1',
#   'trip_total': '9.5',
#   'payment_type': 'Cash',
#   'company': 'Taxi Affiliation Services',
#   'pickup_centroid_latitude': '41.899602111',
#   'pickup_centroid_longitude': '-87.633308037',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6333080367, 41.899602111]},
#   'dropoff_centroid_latitude': '41.878865584',
#   'dropoff_centroid_longitude': '-87.625192142',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6251921424, 41.8788655841]}},
#  {'trip_id': '86f2f6a97b8208d4d02be12708d5275cca8eeaab',
#   'taxi_id': '1a1189d1e9f4f676bbeaf49903912684b94453576a234f5d936dd20a4c68663576906b385222d8e26caaacefdad8a154d7dd0cda53857350c7ea755e7a51bcfc',
#   'trip_start_timestamp': '2023-11-27T23:45:00.000',
#   'trip_end_timestamp': '2023-11-28T00:00:00.000',
#   'trip_seconds': '229',
#   'trip_miles': '0.4',
#   'pickup_census_tract': '17031081600',
#   'dropoff_census_tract': '17031081800',
#   'pickup_community_area': '8',
#   'dropoff_community_area': '8',
#   'fare': '4.5',
#   'tips': '0',
#   'tolls': '0',
#   'extras': '0',
#   'trip_total': '4.5',
#   'payment_type': 'Cash',
#   'company': 'Sun Taxi',
#   'pickup_centroid_latitude': '41.892072635',
#   'pickup_centroid_longitude': '-87.628874157',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6288741572, 41.8920726347]},
#   'dropoff_centroid_latitude': '41.89321636',
#   'dropoff_centroid_longitude': '-87.63784421',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6378442095, 41.8932163595]}},
#  {'trip_id': '7d1b261cd7017845dfd42cf211a3b8c94ea84116',
#   'taxi_id': '50dc36f1bedff89d1aa67f769828175e41f873e23fad7bbcefff450076dac1c206b05b8877ff786a626f6f90a148eea89b3dc50035799ca48e6509171db91d2b',
#   'trip_start_timestamp': '2023-11-27T23:45:00.000',
#   'trip_end_timestamp': '2023-11-27T23:45:00.000',
#   'trip_seconds': '11',
#   'trip_miles': '0',
#   'pickup_community_area': '8',
#   'dropoff_community_area': '8',
#   'fare': '68',
#   'tips': '10.28',
#   'tolls': '0',
#   'extras': '0',
#   'trip_total': '78.78',
#   'payment_type': 'Credit Card',
#   'company': 'Flash Cab',
#   'pickup_centroid_latitude': '41.899602111',
#   'pickup_centroid_longitude': '-87.633308037',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6333080367, 41.899602111]},
#   'dropoff_centroid_latitude': '41.899602111',
#   'dropoff_centroid_longitude': '-87.633308037',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6333080367, 41.899602111]}},
#  {'trip_id': '73b42045965bfa50151dcdcc989fae90266bf35a',
#   'taxi_id': 'a0a886ad03fbdf977af36c2495d1f737bb58e23484818c8d7dc01578af65642104024f22b6bddc7b22564e196e24e7fef1b158ad66bb70dac7491a6892d138bf',
#   'trip_start_timestamp': '2023-11-27T23:45:00.000',
#   'trip_end_timestamp': '2023-11-27T23:45:00.000',
#   'trip_seconds': '621',
#   'trip_miles': '5.04',
#   'pickup_community_area': '32',
#   'dropoff_community_area': '6',
#   'fare': '15',
#   'tips': '2.32',
#   'tolls': '0',
#   'extras': '0',
#   'trip_total': '17.82',
#   'payment_type': 'Credit Card',
#   'company': 'Flash Cab',
#   'pickup_centroid_latitude': '41.878865584',
#   'pickup_centroid_longitude': '-87.625192142',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6251921424, 41.8788655841]},
#   'dropoff_centroid_latitude': '41.944226601',
#   'dropoff_centroid_longitude': '-87.655998182',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6559981815, 41.9442266014]}},
#  {'trip_id': '7476308bdbdc753b6b2840702d420408b974de52',
#   'taxi_id': '52ca9a97ddafa021d0588c76040babc4e8ddeb917c9dc4a15b72e7348617e0dd086b830349f04a33a5d29e5eee3dfb7ec11abc598e1748a2b70b497662558f96',
#   'trip_start_timestamp': '2023-11-27T23:45:00.000',
#   'trip_end_timestamp': '2023-11-27T23:45:00.000',
#   'trip_seconds': '5',
#   'trip_miles': '0',
#   'pickup_community_area': '76',
#   'dropoff_community_area': '76',
#   'fare': '3.25',
#   'tips': '0',
#   'tolls': '0',
#   'extras': '0',
#   'trip_total': '3.25',
#   'payment_type': 'Cash',
#   'company': 'Flash Cab',
#   'pickup_centroid_latitude': '41.980264315',
#   'pickup_centroid_longitude': '-87.913624596',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.913624596, 41.9802643146]},
#   'dropoff_centroid_latitude': '41.980264315',
#   'dropoff_centroid_longitude': '-87.913624596',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.913624596, 41.9802643146]}},
#  {'trip_id': '751a5b48a818b0ddf437023f534cbff99e9281c5',
#   'taxi_id': 'd744f003d8f56f6a8b53b97c0589575fa9a975e9d12f66b59a3122c36a9c9f16837e9b8227646af13d292471984c2ca5eb8409c75638dd9fe362f7150307d3d4',
#   'trip_start_timestamp': '2023-11-27T23:45:00.000',
#   'trip_end_timestamp': '2023-11-27T23:45:00.000',
#   'trip_seconds': '6',
#   'trip_miles': '0',
#   'fare': '49',
#   'tips': '9.9',
#   'tolls': '0',
#   'extras': '0',
#   'trip_total': '59.4',
#   'payment_type': 'Credit Card',
#   'company': 'Flash Cab'},
#  {'trip_id': '6d7a859fcd81bed55b76a769d08f1413b155ec18',
#   'taxi_id': '77c7e7dc3fdd00c2c474a025551a3a459b8f748d6d27a2c3295d12fa8a38d71e04656c0ee8394f9cd68641aa08867039af4d6eb77f99e53afd158833314348a9',
#   'trip_start_timestamp': '2023-11-27T23:45:00.000',
#   'trip_end_timestamp': '2023-11-28T00:15:00.000',
#   'trip_seconds': '1500',
#   'trip_miles': '11.5',
#   'pickup_community_area': '76',
#   'dropoff_community_area': '13',
#   'fare': '30.25',
#   'tips': '6.95',
#   'tolls': '0',
#   'extras': '4',
#   'trip_total': '41.2',
#   'payment_type': 'Credit Card',
#   'company': 'Taxi Affiliation Services',
#   'pickup_centroid_latitude': '41.980264315',
#   'pickup_centroid_longitude': '-87.913624596',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.913624596, 41.9802643146]},
#   'dropoff_centroid_latitude': '41.983636307',
#   'dropoff_centroid_longitude': '-87.723583185',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.7235831853, 41.9836363072]}},
#  {'trip_id': '703b41275eb87a1609556ef3a63c77bc934b4b0a',
#   'taxi_id': '008e09771fc5d90e65eec92b1bec3a46d753cc1acabf61d72f9dc175b9dd672890c6fa5f0ff4e549c7719425db84a314c423e1c2fcd99c9d0b9a58d17d733883',
#   'trip_start_timestamp': '2023-11-27T23:45:00.000',
#   'trip_end_timestamp': '2023-11-28T00:15:00.000',
#   'trip_seconds': '1440',
#   'trip_miles': '17.7',
#   'pickup_census_tract': '17031980000',
#   'dropoff_census_tract': '17031839100',
#   'pickup_community_area': '76',
#   'dropoff_community_area': '32',
#   'fare': '43.75',
#   'tips': '2',
#   'tolls': '0',
#   'extras': '4',
#   'trip_total': '49.75',
#   'payment_type': 'Credit Card',
#   'company': 'Taxi Affiliation Services',
#   'pickup_centroid_latitude': '41.97907082',
#   'pickup_centroid_longitude': '-87.903039661',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.9030396611, 41.9790708201]},
#   'dropoff_centroid_latitude': '41.880994471',
#   'dropoff_centroid_longitude': '-87.632746489',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6327464887, 41.8809944707]}},
#  {'trip_id': '666dee0b1303bbd4730ac401a0b6e304e1e9ab71',
#   'taxi_id': 'bb4e75d3065311c33024a434640731c43fd2cf9e4482eb9e17cbf9f0ff0ed005455ffe22797df66b7467489a738e7be52c5983e16615b31c7c1d6af3ee0eb965',
#   'trip_start_timestamp': '2023-11-27T23:45:00.000',
#   'trip_end_timestamp': '2023-11-27T23:45:00.000',
#   'trip_seconds': '480',
#   'trip_miles': '0',
#   'pickup_census_tract': '17031839100',
#   'dropoff_census_tract': '17031081500',
#   'pickup_community_area': '32',
#   'dropoff_community_area': '8',
#   'fare': '6.75',
#   'tips': '0',
#   'tolls': '0',
#   'extras': '0',
#   'trip_total': '6.75',
#   'payment_type': 'Cash',
#   'company': 'Taxi Affiliation Services',
#   'pickup_centroid_latitude': '41.880994471',
#   'pickup_centroid_longitude': '-87.632746489',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6327464887, 41.8809944707]},
#   'dropoff_centroid_latitude': '41.892507781',
#   'dropoff_centroid_longitude': '-87.626214906',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6262149064, 41.8925077809]}},
#  {'trip_id': '6a33c69d01c9c5ccf129c3a5c34051f028f717c9',
#   'taxi_id': 'c531f081cad817a366cbae2254ce7a3bb370394b3b0f1399dfc8781333c3565ca188035bbff4d1d7652181b79712c103d01ab168cb6ca2580f2da4b324cb00a5',
#   'trip_start_timestamp': '2023-11-27T23:45:00.000',
#   'trip_end_timestamp': '2023-11-27T23:45:00.000',
#   'trip_seconds': '135',
#   'trip_miles': '0.55',
#   'pickup_community_area': '8',
#   'dropoff_community_area': '8',
#   'fare': '4.5',
#   'tips': '0',
#   'tolls': '0',
#   'extras': '0',
#   'trip_total': '4.5',
#   'payment_type': 'Cash',
#   'company': 'Flash Cab',
#   'pickup_centroid_latitude': '41.899602111',
#   'pickup_centroid_longitude': '-87.633308037',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6333080367, 41.899602111]},
#   'dropoff_centroid_latitude': '41.899602111',
#   'dropoff_centroid_longitude': '-87.633308037',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6333080367, 41.899602111]}},
#  {'trip_id': '67c0649f4fea6cc5e26cb903c8afa9f6dbf548e8',
#   'taxi_id': '0f831bff43d83f396f2e4950126c6137dcdb60fb4c8580ffe860203747a83a789b22f2f9e4fbdd0dd8ed8c310366d8935228ddbcadf708fb9691ca5dd1b6c802',
#   'trip_start_timestamp': '2023-11-27T23:45:00.000',
#   'trip_end_timestamp': '2023-11-28T00:15:00.000',
#   'trip_seconds': '1575',
#   'trip_miles': '20.99',
#   'pickup_community_area': '76',
#   'dropoff_community_area': '60',
#   'fare': '51',
#   'tips': '11.4',
#   'tolls': '0',
#   'extras': '5.5',
#   'trip_total': '68.4',
#   'payment_type': 'Mobile',
#   'company': 'Sun Taxi',
#   'pickup_centroid_latitude': '41.980264315',
#   'pickup_centroid_longitude': '-87.913624596',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.913624596, 41.9802643146]},
#   'dropoff_centroid_latitude': '41.836150155',
#   'dropoff_centroid_longitude': '-87.648787952',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6487879519, 41.8361501547]}},
#  {'trip_id': '611ff8197807d88ed54b884a747e3af37cdbbe66',
#   'taxi_id': '8251ae1a546f4f2079a91222c214a11b5a660aad9861a8972e5ef6690c087cc4463037d37cdec907dbca2e57813105d2a580ab97fe913a908b3d9aa15eed099f',
#   'trip_start_timestamp': '2023-11-27T23:45:00.000',
#   'trip_end_timestamp': '2023-11-28T00:00:00.000',
#   'trip_seconds': '915',
#   'trip_miles': '11.25',
#   'pickup_community_area': '56',
#   'dropoff_community_area': '24',
#   'fare': '29.25',
#   'tips': '0',
#   'tolls': '0',
#   'extras': '1',
#   'trip_total': '30.25',
#   'payment_type': 'Prcard',
#   'company': 'City Service',
#   'pickup_centroid_latitude': '41.79259236',
#   'pickup_centroid_longitude': '-87.769615453',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.7696154528, 41.7925923603]},
#   'dropoff_centroid_latitude': '41.901206994',
#   'dropoff_centroid_longitude': '-87.676355989',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6763559892, 41.9012069941]}},
#  {'trip_id': '580b2bdd86f3483ea5bf6d96aebca03891c1366f',
#   'taxi_id': '9a423881d4046f5590943c08ec5e58d59f5ebd91fe26aa9ef49ad0dfe587e3d3a78dc5e2d214e4d42120e5296ebadeb100494177de8b0fc8ef6a1b3e5290669b',
#   'trip_start_timestamp': '2023-11-27T23:45:00.000',
#   'trip_end_timestamp': '2023-11-28T00:15:00.000',
#   'trip_seconds': '1320',
#   'trip_miles': '10.3',
#   'pickup_community_area': '24',
#   'dropoff_community_area': '6',
#   'fare': '27.75',
#   'tips': '0',
#   'tolls': '0',
#   'extras': '0',
#   'trip_total': '27.75',
#   'payment_type': 'Unknown',
#   'company': 'Taxi Affiliation Services',
#   'pickup_centroid_latitude': '41.901206994',
#   'pickup_centroid_longitude': '-87.676355989',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6763559892, 41.9012069941]},
#   'dropoff_centroid_latitude': '41.944226601',
#   'dropoff_centroid_longitude': '-87.655998182',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6559981815, 41.9442266014]}},
#  {'trip_id': '5459de812bab1f7ca755d3751d73969730af9119',
#   'taxi_id': 'aee6a1f2577e5f670e300733aca9b27ad8fecd22425d14f9188733f612d6380edc507e2a0a3c1e6e198d356994d9e4b504f0656079367ec171433fe1df9751df',
#   'trip_start_timestamp': '2023-11-27T23:45:00.000',
#   'trip_end_timestamp': '2023-11-28T00:15:00.000',
#   'trip_seconds': '1503',
#   'trip_miles': '18.13',
#   'pickup_census_tract': '17031980000',
#   'dropoff_census_tract': '17031081500',
#   'pickup_community_area': '76',
#   'dropoff_community_area': '8',
#   'fare': '45',
#   'tips': '9.9',
#   'tolls': '0',
#   'extras': '4',
#   'trip_total': '59.4',
#   'payment_type': 'Credit Card',
#   'company': 'Taxicab Insurance Agency Llc',
#   'pickup_centroid_latitude': '41.97907082',
#   'pickup_centroid_longitude': '-87.903039661',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.9030396611, 41.9790708201]},
#   'dropoff_centroid_latitude': '41.892507781',
#   'dropoff_centroid_longitude': '-87.626214906',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6262149064, 41.8925077809]}},
#  {'trip_id': '592b461ccb0ac585f94ae1d3796c878d6b89cda6',
#   'taxi_id': '9a423881d4046f5590943c08ec5e58d59f5ebd91fe26aa9ef49ad0dfe587e3d3a78dc5e2d214e4d42120e5296ebadeb100494177de8b0fc8ef6a1b3e5290669b',
#   'trip_start_timestamp': '2023-11-27T23:45:00.000',
#   'trip_end_timestamp': '2023-11-27T23:45:00.000',
#   'trip_seconds': '60',
#   'trip_miles': '0.1',
#   'pickup_community_area': '24',
#   'dropoff_community_area': '24',
#   'fare': '3.5',
#   'tips': '0',
#   'tolls': '0',
#   'extras': '0',
#   'trip_total': '3.5',
#   'payment_type': 'Cash',
#   'company': 'Taxi Affiliation Services',
#   'pickup_centroid_latitude': '41.901206994',
#   'pickup_centroid_longitude': '-87.676355989',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6763559892, 41.9012069941]},
#   'dropoff_centroid_latitude': '41.901206994',
#   'dropoff_centroid_longitude': '-87.676355989',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6763559892, 41.9012069941]}},
#  {'trip_id': '49cb22eb6641c26d8e7dcd228e20c112ec381b52',
#   'taxi_id': 'e64275101114ec6cfacc200c2bab09d7d4e128b5f6fd4cad1db03ff64b96c9bfbcfcf1c77239fd43d897539f8cbfc7e8da784bb7cebe0a7b83bf21233a46fb4b',
#   'trip_start_timestamp': '2023-11-27T23:45:00.000',
#   'trip_end_timestamp': '2023-11-28T00:00:00.000',
#   'trip_seconds': '433',
#   'trip_miles': '1.94',
#   'pickup_community_area': '28',
#   'dropoff_community_area': '8',
#   'fare': '8',
#   'tips': '3',
#   'tolls': '0',
#   'extras': '0',
#   'trip_total': '11.5',
#   'payment_type': 'Mobile',
#   'company': 'Chicago Independents',
#   'pickup_centroid_latitude': '41.874005383',
#   'pickup_centroid_longitude': '-87.66351755',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6635175498, 41.874005383]},
#   'dropoff_centroid_latitude': '41.899602111',
#   'dropoff_centroid_longitude': '-87.633308037',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6333080367, 41.899602111]}},
#  {'trip_id': '446344a96caef48498310e4081bd5ee2eb51a309',
#   'taxi_id': '3edf5aaee7cd5378f854cca9e574820e57badb93344e0c367b70b3e39f3efb4484a3da00e6553a0c711580349369dab3969adb9845c6fd8bc63cce362a80da8f',
#   'trip_start_timestamp': '2023-11-27T23:45:00.000',
#   'trip_end_timestamp': '2023-11-28T00:00:00.000',
#   'trip_seconds': '989',
#   'trip_miles': '13.8',
#   'pickup_community_area': '76',
#   'dropoff_community_area': '22',
#   'fare': '34.25',
#   'tips': '7.95',
#   'tolls': '0',
#   'extras': '5',
#   'trip_total': '47.7',
#   'payment_type': 'Credit Card',
#   'company': '5 Star Taxi',
#   'pickup_centroid_latitude': '41.980264315',
#   'pickup_centroid_longitude': '-87.913624596',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.913624596, 41.9802643146]},
#   'dropoff_centroid_latitude': '41.92276062',
#   'dropoff_centroid_longitude': '-87.699155343',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6991553432, 41.9227606205]}},
#  {'trip_id': '4249af28739f75a19896edc657112408d788d50a',
#   'taxi_id': '561fbb8af15689fe33fb11b96905cfb95d11ac44700c1a476e474b9b19d4dc24fec8cbfe3df913dc2ee78f919bd0b1cb416be0bc3b0a431d4335bfae2df63278',
#   'trip_start_timestamp': '2023-11-27T23:45:00.000',
#   'trip_end_timestamp': '2023-11-27T23:45:00.000',
#   'trip_seconds': '467',
#   'trip_miles': '1.92',
#   'pickup_census_tract': '17031081500',
#   'dropoff_census_tract': '17031833000',
#   'pickup_community_area': '8',
#   'dropoff_community_area': '28',
#   'fare': '8.25',
#   'tips': '2',
#   'tolls': '0',
#   'extras': '0',
#   'trip_total': '10.75',
#   'payment_type': 'Credit Card',
#   'company': 'Flash Cab',
#   'pickup_centroid_latitude': '41.892507781',
#   'pickup_centroid_longitude': '-87.626214906',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6262149064, 41.8925077809]},
#   'dropoff_centroid_latitude': '41.88528132',
#   'dropoff_centroid_longitude': '-87.6572332',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6572331997, 41.8852813201]}},
#  {'trip_id': '3afd803c2d0992bfbc78f7f289111426ac6850bd',
#   'taxi_id': '1acb04c857af31081be646567d63ac255fd46acef2c3f13733692d8f38ef364e77fe4d8439adcaf33d28c3f2234a4e51c43b2523e6dfcff525739e9cb6903bb6',
#   'trip_start_timestamp': '2023-11-27T23:45:00.000',
#   'trip_end_timestamp': '2023-11-27T23:45:00.000',
#   'trip_seconds': '49',
#   'trip_miles': '0',
#   'pickup_community_area': '22',
#   'dropoff_community_area': '22',
#   'fare': '48',
#   'tips': '14.55',
#   'tolls': '0',
#   'extras': '0',
#   'trip_total': '63.05',
#   'payment_type': 'Credit Card',
#   'company': 'Globe Taxi',
#   'pickup_centroid_latitude': '41.92276062',
#   'pickup_centroid_longitude': '-87.699155343',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6991553432, 41.9227606205]},
#   'dropoff_centroid_latitude': '41.92276062',
#   'dropoff_centroid_longitude': '-87.699155343',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6991553432, 41.9227606205]}},
#  {'trip_id': '398652994387edf0db4627a8441e6b8c9c963260',
#   'taxi_id': '3f7d8054c7c41782afe5526091ff0e5db98ba3652db8e855a15b760e834c6e592d9ed63c23a9924251f77cb55fa58abd6b9e9d6e3df13cb1f82c4fe62e2415f3',
#   'trip_start_timestamp': '2023-11-27T23:45:00.000',
#   'trip_end_timestamp': '2023-11-28T00:15:00.000',
#   'trip_seconds': '1762',
#   'trip_miles': '13.36',
#   'pickup_community_area': '76',
#   'dropoff_community_area': '3',
#   'fare': '35',
#   'tips': '11.85',
#   'tolls': '0',
#   'extras': '4',
#   'trip_total': '51.35',
#   'payment_type': 'Credit Card',
#   'company': 'Sun Taxi',
#   'pickup_centroid_latitude': '41.980264315',
#   'pickup_centroid_longitude': '-87.913624596',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.913624596, 41.9802643146]},
#   'dropoff_centroid_latitude': '41.96581197',
#   'dropoff_centroid_longitude': '-87.655878786',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6558787862, 41.96581197]}},
#  {'trip_id': '379db9d02718ac9dc83b3f195612a05f0b1fa3a5',
#   'taxi_id': 'bee9782d8d7310bc1b902a8fe547baf0da4c95165bd81fa8562135699154d78cafe9b966c231126dcc9db2ef96ca27cee093190d4162697d8fc0c5a27403afe2',
#   'trip_start_timestamp': '2023-11-27T23:45:00.000',
#   'trip_end_timestamp': '2023-11-28T00:15:00.000',
#   'trip_seconds': '1155',
#   'trip_miles': '10.97',
#   'pickup_community_area': '56',
#   'dropoff_community_area': '8',
#   'fare': '28.75',
#   'tips': '8.56',
#   'tolls': '0',
#   'extras': '5',
#   'trip_total': '42.81',
#   'payment_type': 'Credit Card',
#   'company': 'City Service',
#   'pickup_centroid_latitude': '41.79259236',
#   'pickup_centroid_longitude': '-87.769615453',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.7696154528, 41.7925923603]},
#   'dropoff_centroid_latitude': '41.899602111',
#   'dropoff_centroid_longitude': '-87.633308037',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6333080367, 41.899602111]}},
#  {'trip_id': '3b3d57220ecfc6bef233bb63e4e615654cb4048f',
#   'taxi_id': 'eead1e2c21b26570411277cb384d3d8d072fc6da913b0617c841cfd3f6cdf40c508395c589a56d12afd2ec4002948fdeb56cb029227274b760200d7c0e2dcb1c',
#   'trip_start_timestamp': '2023-11-27T23:45:00.000',
#   'trip_end_timestamp': '2023-11-28T00:00:00.000',
#   'trip_seconds': '1459',
#   'trip_miles': '18.38',
#   'pickup_census_tract': '17031980000',
#   'dropoff_census_tract': '17031320100',
#   'pickup_community_area': '76',
#   'dropoff_community_area': '32',
#   'fare': '45',
#   'tips': '10.1',
#   'tolls': '0',
#   'extras': '5',
#   'trip_total': '60.6',
#   'payment_type': 'Credit Card',
#   'company': '5 Star Taxi',
#   'pickup_centroid_latitude': '41.97907082',
#   'pickup_centroid_longitude': '-87.903039661',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.9030396611, 41.9790708201]},
#   'dropoff_centroid_latitude': '41.884987192',
#   'dropoff_centroid_longitude': '-87.620992913',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6209929134, 41.8849871918]}},
#  {'trip_id': '3174dff8a891f7334aef3bc777365b340389f9a7',
#   'taxi_id': '3b95cedc13d4a99243e1974616a6a25267c25878336faa586d4372370c847c3618753718dca887e3713efb476a5af11bc5f5a86c9785c9f749ca45f3f8be4764',
#   'trip_start_timestamp': '2023-11-27T23:45:00.000',
#   'trip_end_timestamp': '2023-11-28T00:15:00.000',
#   'trip_seconds': '1620',
#   'trip_miles': '1',
#   'pickup_community_area': '56',
#   'dropoff_community_area': '6',
#   'fare': '40.75',
#   'tips': '9.05',
#   'tolls': '0',
#   'extras': '4',
#   'trip_total': '53.8',
#   'payment_type': 'Credit Card',
#   'company': 'Taxi Affiliation Services',
#   'pickup_centroid_latitude': '41.79259236',
#   'pickup_centroid_longitude': '-87.769615453',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.7696154528, 41.7925923603]},
#   'dropoff_centroid_latitude': '41.944226601',
#   'dropoff_centroid_longitude': '-87.655998182',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6559981815, 41.9442266014]}},
#  {'trip_id': '31928f2733a33f3d9cce4472b2761bc51045aa2b',
#   'taxi_id': '4beea83b52b76272fc17484086dadd3d1ea3fe1a8f38f821400f49b4392f695e7b40e2a39938ba1a70d781a5f7775cb20fdbada6928bab8a2d80ec1323a17b88',
#   'trip_start_timestamp': '2023-11-27T23:45:00.000',
#   'trip_end_timestamp': '2023-11-28T00:00:00.000',
#   'trip_seconds': '960',
#   'trip_miles': '3.7',
#   'pickup_community_area': '28',
#   'dropoff_community_area': '32',
#   'fare': '13',
#   'tips': '4.85',
#   'tolls': '0',
#   'extras': '6',
#   'trip_total': '23.85',
#   'payment_type': 'Credit Card',
#   'company': 'Taxicab Insurance Agency, LLC',
#   'pickup_centroid_latitude': '41.874005383',
#   'pickup_centroid_longitude': '-87.66351755',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6635175498, 41.874005383]},
#   'dropoff_centroid_latitude': '41.878865584',
#   'dropoff_centroid_longitude': '-87.625192142',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6251921424, 41.8788655841]}},
#  {'trip_id': '355d9681a3bd674983b936fe3e43a89e168b3faf',
#   'taxi_id': '58ba68a5ed675f1dd391281aa8853366f7759face1a388abf6b64c8a9e5f24d65de820eb60b293a3a8b6dbd48e8019439535d20faf2576989701a5936c4e77b8',
#   'trip_start_timestamp': '2023-11-27T23:45:00.000',
#   'trip_end_timestamp': '2023-11-27T23:45:00.000',
#   'trip_seconds': '300',
#   'trip_miles': '0',
#   'pickup_census_tract': '17031320100',
#   'dropoff_census_tract': '17031081403',
#   'pickup_community_area': '32',
#   'dropoff_community_area': '8',
#   'fare': '5.75',
#   'tips': '2',
#   'tolls': '0',
#   'extras': '0',
#   'trip_total': '7.75',
#   'payment_type': 'Credit Card',
#   'company': 'Taxi Affiliation Services',
#   'pickup_centroid_latitude': '41.884987192',
#   'pickup_centroid_longitude': '-87.620992913',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6209929134, 41.8849871918]},
#   'dropoff_centroid_latitude': '41.890922026',
#   'dropoff_centroid_longitude': '-87.618868355',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6188683546, 41.8909220259]}},
#  {'trip_id': '35feceb014019ebe198dfeae0682cf193be20003',
#   'taxi_id': 'f6b057fe5c09fb2968b2d9aee87ba36e9c50f6c343ffdde036b0096909f605f459a1f043063bb4d6c0e386675ca935e3174f37708cd9527557da3f6de3d59c71',
#   'trip_start_timestamp': '2023-11-27T23:45:00.000',
#   'trip_end_timestamp': '2023-11-28T00:00:00.000',
#   'trip_seconds': '1005',
#   'trip_miles': '12.11',
#   'pickup_community_area': '36',
#   'dropoff_community_area': '3',
#   'fare': '30.75',
#   'tips': '0',
#   'tolls': '0',
#   'extras': '0',
#   'trip_total': '30.75',
#   'payment_type': 'Prcard',
#   'company': 'Flash Cab',
#   'pickup_centroid_latitude': '41.82371281',
#   'pickup_centroid_longitude': '-87.602350437',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6023504372, 41.8237128095]},
#   'dropoff_centroid_latitude': '41.96581197',
#   'dropoff_centroid_longitude': '-87.655878786',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6558787862, 41.96581197]}},
#  {'trip_id': '2f8ad396bc369eada7547b46650d33dae0271afe',
#   'taxi_id': '35057a271731c5b976bda25efe85aa0c1901d0a5fc9ba2b7068508375a4c43033b282303a439c95d4ef479c592268f31ac7eb0b3db8f3998aaa79e82458a1d71',
#   'trip_start_timestamp': '2023-11-27T23:45:00.000',
#   'trip_end_timestamp': '2023-11-27T23:45:00.000',
#   'trip_seconds': '420',
#   'trip_miles': '1',
#   'pickup_census_tract': '17031081201',
#   'dropoff_census_tract': '17031320100',
#   'pickup_community_area': '8',
#   'dropoff_community_area': '32',
#   'fare': '6.5',
#   'tips': '0',
#   'tolls': '0',
#   'extras': '1.5',
#   'trip_total': '8',
#   'payment_type': 'Cash',
#   'company': 'Taxicab Insurance Agency, LLC',
#   'pickup_centroid_latitude': '41.899155613',
#   'pickup_centroid_longitude': '-87.626210532',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6262105324, 41.8991556134]},
#   'dropoff_centroid_latitude': '41.884987192',
#   'dropoff_centroid_longitude': '-87.620992913',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6209929134, 41.8849871918]}},
#  {'trip_id': '2ffc6570964faa037c216bd2d7c841cb528078e0',
#   'taxi_id': '8105e73e69f876853cb9f5053fed42a9769b84588fa29b5675a78a4f63ef4ea192b7cb6c93e9d2ceda36030b27b5d6a7692574b1b858d30203ae6e3cc9d3ac8a',
#   'trip_start_timestamp': '2023-11-27T23:45:00.000',
#   'trip_end_timestamp': '2023-11-28T00:00:00.000',
#   'trip_seconds': '1501',
#   'trip_miles': '14.36',
#   'pickup_community_area': '76',
#   'dropoff_community_area': '6',
#   'fare': '36.75',
#   'tips': '0',
#   'tolls': '0',
#   'extras': '4',
#   'trip_total': '40.75',
#   'payment_type': 'Cash',
#   'company': 'Flash Cab',
#   'pickup_centroid_latitude': '41.980264315',
#   'pickup_centroid_longitude': '-87.913624596',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.913624596, 41.9802643146]},
#   'dropoff_centroid_latitude': '41.944226601',
#   'dropoff_centroid_longitude': '-87.655998182',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6559981815, 41.9442266014]}},
#  {'trip_id': '2db08d0a0fd61cc930479bf6a66a563b8f746231',
#   'taxi_id': '3c0868927194b2901fad4463dea178de530dc0ed3f7888c5720390737f01deab51fa305e015456e35d4fdf033da0186c813d9ef637061e033e3598caf7e9d49d',
#   'trip_start_timestamp': '2023-11-27T23:45:00.000',
#   'trip_end_timestamp': '2023-11-28T00:00:00.000',
#   'trip_seconds': '1028',
#   'trip_miles': '11.2',
#   'pickup_community_area': '76',
#   'dropoff_community_area': '21',
#   'fare': '29.5',
#   'tips': '8.5',
#   'tolls': '0',
#   'extras': '4',
#   'trip_total': '42.5',
#   'payment_type': 'Credit Card',
#   'company': 'Sun Taxi',
#   'pickup_centroid_latitude': '41.980264315',
#   'pickup_centroid_longitude': '-87.913624596',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.913624596, 41.9802643146]},
#   'dropoff_centroid_latitude': '41.938666196',
#   'dropoff_centroid_longitude': '-87.711210593',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.7112105933, 41.9386661962]}},
#  {'trip_id': '249e8c2885ae5f72ad853cb47cccb8504a5f2f72',
#   'taxi_id': 'deec568f18d18fb40292b918b82311ac8006ada6a8a1fff177f4bab2b5925b4c0712813919884a696c8fa2bde1d0a283d372f72024785b3d9ef2b8d18857b0b4',
#   'trip_start_timestamp': '2023-11-27T23:45:00.000',
#   'trip_end_timestamp': '2023-11-27T23:45:00.000',
#   'trip_seconds': '128',
#   'trip_miles': '0.44',
#   'pickup_community_area': '8',
#   'dropoff_community_area': '8',
#   'fare': '4.25',
#   'tips': '0',
#   'tolls': '0',
#   'extras': '0',
#   'trip_total': '4.25',
#   'payment_type': 'Cash',
#   'company': 'City Service',
#   'pickup_centroid_latitude': '41.899602111',
#   'pickup_centroid_longitude': '-87.633308037',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6333080367, 41.899602111]},
#   'dropoff_centroid_latitude': '41.899602111',
#   'dropoff_centroid_longitude': '-87.633308037',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6333080367, 41.899602111]}},
#  {'trip_id': '231f35b6f2c8e2d443c62623be579a7bafe88bba',
#   'taxi_id': '4fd6cc40972b7fd3e026723f0fc4928d7f3159ea0e0822b1cb2cb763e6d3d419be787835d9dd08715f7447db097fd3ee08a599372ed9c2e99978e0447d6fa1d3',
#   'trip_start_timestamp': '2023-11-27T23:45:00.000',
#   'trip_end_timestamp': '2023-11-27T23:45:00.000',
#   'trip_seconds': '420',
#   'trip_miles': '1.5',
#   'pickup_census_tract': '17031839100',
#   'dropoff_census_tract': '17031320600',
#   'pickup_community_area': '32',
#   'dropoff_community_area': '32',
#   'fare': '7.5',
#   'tips': '2',
#   'tolls': '0',
#   'extras': '0',
#   'trip_total': '9.5',
#   'payment_type': 'Credit Card',
#   'company': 'Taxi Affiliation Services',
#   'pickup_centroid_latitude': '41.880994471',
#   'pickup_centroid_longitude': '-87.632746489',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6327464887, 41.8809944707]},
#   'dropoff_centroid_latitude': '41.870607372',
#   'dropoff_centroid_longitude': '-87.622172937',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6221729369, 41.8706073724]}},
#  {'trip_id': '157498eff0b1e9c0297c0fa22c4a0e05c83c4827',
#   'taxi_id': '68aae28119a6c274b4957fa18111a0883d0c433381d52e173d0571d340ddab1de60a68ee6aa19ce8d0e1f34cb653a202f563861123a947e3f019cce0c024271e',
#   'trip_start_timestamp': '2023-11-27T23:45:00.000',
#   'trip_end_timestamp': '2023-11-27T23:45:00.000',
#   'trip_seconds': '300',
#   'trip_miles': '0',
#   'pickup_community_area': '33',
#   'dropoff_community_area': '32',
#   'fare': '6.75',
#   'tips': '1.5',
#   'tolls': '0',
#   'extras': '0',
#   'trip_total': '8.25',
#   'payment_type': 'Credit Card',
#   'company': 'Taxi Affiliation Services',
#   'pickup_centroid_latitude': '41.857183858',
#   'pickup_centroid_longitude': '-87.620334624',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6203346241, 41.8571838585]},
#   'dropoff_centroid_latitude': '41.878865584',
#   'dropoff_centroid_longitude': '-87.625192142',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6251921424, 41.8788655841]}},
#  {'trip_id': '0f3d89839b4df47d8b74bb8e6331e2fa174e764e',
#   'taxi_id': 'd69cc05e25a10864b217d3c7aff9cccce2c11e38a787c4ecc18b294a439202df7220e52b65c27cde8a5e1dd93f866ab9e210126630c957a890ce257ff594df58',
#   'trip_start_timestamp': '2023-11-27T23:45:00.000',
#   'trip_end_timestamp': '2023-11-28T00:00:00.000',
#   'trip_seconds': '1253',
#   'trip_miles': '18.68',
#   'pickup_community_area': '76',
#   'dropoff_community_area': '32',
#   'fare': '45.5',
#   'tips': '10',
#   'tolls': '0',
#   'extras': '4',
#   'trip_total': '60',
#   'payment_type': 'Mobile',
#   'company': 'City Service',
#   'pickup_centroid_latitude': '41.980264315',
#   'pickup_centroid_longitude': '-87.913624596',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.913624596, 41.9802643146]},
#   'dropoff_centroid_latitude': '41.878865584',
#   'dropoff_centroid_longitude': '-87.625192142',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6251921424, 41.8788655841]}},
#  {'trip_id': '0b981eb7a875b9e9a759c4decf46cea50b6d09ca',
#   'taxi_id': '1f041942ef7c61fea34c62c89aea8231e4277ca158d54ef1a738be59f3099e32f7f6626f22cdd82e425bdff13f179feb3f1b12f34b8c1addd999239551c17d2d',
#   'trip_start_timestamp': '2023-11-27T23:45:00.000',
#   'trip_end_timestamp': '2023-11-27T23:45:00.000',
#   'trip_seconds': '483',
#   'trip_miles': '1.49',
#   'pickup_community_area': '32',
#   'dropoff_community_area': '8',
#   'fare': '7.75',
#   'tips': '0',
#   'tolls': '0',
#   'extras': '0',
#   'trip_total': '7.75',
#   'payment_type': 'Cash',
#   'company': 'Flash Cab',
#   'pickup_centroid_latitude': '41.878865584',
#   'pickup_centroid_longitude': '-87.625192142',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6251921424, 41.8788655841]},
#   'dropoff_centroid_latitude': '41.899602111',
#   'dropoff_centroid_longitude': '-87.633308037',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6333080367, 41.899602111]}},
#  {'trip_id': '0898c0328f6904696df6c35dceabd4e55cb36445',
#   'taxi_id': 'f4bc2acfbb68d505b7ca37f8553ab1fc28a2686429b55d0fab2d4d1838e1ffe2316dbf7a4cf417c3e947a62734f6b7dd91f7656ab4f9d5ed13dd8d24a8f87f89',
#   'trip_start_timestamp': '2023-11-27T23:45:00.000',
#   'trip_end_timestamp': '2023-11-27T23:45:00.000',
#   'trip_seconds': '0',
#   'trip_miles': '0',
#   'pickup_community_area': '76',
#   'dropoff_community_area': '76',
#   'fare': '3.25',
#   'tips': '0',
#   'tolls': '0',
#   'extras': '4',
#   'trip_total': '7.25',
#   'payment_type': 'Cash',
#   'company': 'Chicago City Taxi Association',
#   'pickup_centroid_latitude': '41.980264315',
#   'pickup_centroid_longitude': '-87.913624596',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.913624596, 41.9802643146]},
#   'dropoff_centroid_latitude': '41.980264315',
#   'dropoff_centroid_longitude': '-87.913624596',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.913624596, 41.9802643146]}},
#  {'trip_id': '02d8032ba4ce2b7365a41b8518690292df08ad6f',
#   'taxi_id': 'e0e1f19080d131afa810280c286bc1f57e78b48fe55e992ac816f33602973ff890905d82df0bec55f791ff66f6f3d7d366281cdb4271de2f2d2acb047b743f32',
#   'trip_start_timestamp': '2023-11-27T23:45:00.000',
#   'trip_end_timestamp': '2023-11-28T00:15:00.000',
#   'trip_seconds': '1825',
#   'trip_miles': '16.23',
#   'pickup_community_area': '56',
#   'dropoff_community_area': '7',
#   'fare': '41.25',
#   'tips': '0',
#   'tolls': '0',
#   'extras': '4',
#   'trip_total': '45.75',
#   'payment_type': 'Credit Card',
#   'company': 'Star North Taxi Management Llc',
#   'pickup_centroid_latitude': '41.79259236',
#   'pickup_centroid_longitude': '-87.769615453',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.7696154528, 41.7925923603]},
#   'dropoff_centroid_latitude': '41.922686284',
#   'dropoff_centroid_longitude': '-87.649488729',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6494887289, 41.9226862843]}},
#  {'trip_id': 'f5bdbd0d37fbb44740edd47007331cb61114f9dc',
#   'taxi_id': '58c784c628cc2b0b77468e6a406acea729301abbc17a6240eed68ac3b5ce5a9378deffab5b2b940db6c83e7c9553eacd8fdb8d10593e071cefffe2b388af3bd7',
#   'trip_start_timestamp': '2023-11-27T23:45:00.000',
#   'trip_end_timestamp': '2023-11-28T00:00:00.000',
#   'trip_seconds': '758',
#   'trip_miles': '6.08',
#   'pickup_community_area': '59',
#   'dropoff_community_area': '32',
#   'fare': '17.75',
#   'tips': '0',
#   'tolls': '0',
#   'extras': '0',
#   'trip_total': '17.75',
#   'payment_type': 'Cash',
#   'company': 'Taxicab Insurance Agency Llc',
#   'pickup_centroid_latitude': '41.829922304',
#   'pickup_centroid_longitude': '-87.672502646',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6725026464, 41.8299223039]},
#   'dropoff_centroid_latitude': '41.878865584',
# ...
#    'coordinates': [-87.6262149064, 41.8925077809]}},
#  {'trip_id': 'db59a0d539af1aef507b40965cfa1a9ff2d03411',
#   'taxi_id': 'f1466ba65ee3a4d113741eee02608ce2a7ab1312802472a86002da5b1a1e14fc80c02c098b2bb775d608e66bcdde28133ef0fc727df48e0b5ceee4905de23ab3',
#   'trip_start_timestamp': '2023-11-27T21:45:00.000',
#   'trip_end_timestamp': '2023-11-27T22:00:00.000',
#   'trip_seconds': '1051',
#   'trip_miles': '13.56',
#   'pickup_community_area': '76',
#   'dropoff_community_area': '24',
#   'fare': '34',
#   'tips': '5',
#   'tolls': '0',
#   'extras': '4',
#   'trip_total': '43.5',
#   'payment_type': 'Credit Card',
#   'company': 'Sun Taxi',
#   'pickup_centroid_latitude': '41.980264315',
#   'pickup_centroid_longitude': '-87.913624596',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.913624596, 41.9802643146]},
#   'dropoff_centroid_latitude': '41.901206994',
#   'dropoff_centroid_longitude': '-87.676355989',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6763559892, 41.9012069941]}},
#  {'trip_id': 'dd277fe3ca61af020e2a589fb482a8c12851b420',
#   'taxi_id': '42560393a9c9b9ae28339f4b5aec77fd89bd49916ad54175d9ee679d69939f973c177065f2816d7990a6663a07270335a4a852190c3258497ba7978edced68c8',
#   'trip_start_timestamp': '2023-11-27T21:45:00.000',
#   'trip_end_timestamp': '2023-11-27T21:45:00.000',
#   'trip_seconds': '738',
#   'trip_miles': '0',
#   'pickup_community_area': '8',
#   'dropoff_community_area': '28',
#   'fare': '9.83',
#   'tips': '1.24',
#   'tolls': '0',
#   'extras': '0',
#   'trip_total': '11.07',
#   'payment_type': 'Mobile',
#   'company': 'Patriot Taxi Dba Peace Taxi Associat',
#   'pickup_centroid_latitude': '41.899602111',
#   'pickup_centroid_longitude': '-87.633308037',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6333080367, 41.899602111]},
#   'dropoff_centroid_latitude': '41.874005383',
#   'dropoff_centroid_longitude': '-87.66351755',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6635175498, 41.874005383]}},
#  {'trip_id': 'da24efa255f86fb7a0da5c1f160f2dbcf9eae52b',
#   'taxi_id': '7ba4f77b2aec943b726e0b2ae455e9505f7798786b4ebb8c3223578311c1bb140c81c85af9d26617ef8719cd01f19058ad8c5747586612284c53da0ef15a73a2',
#   'trip_start_timestamp': '2023-11-27T21:45:00.000',
#   'trip_end_timestamp': '2023-11-27T22:15:00.000',
#   'trip_seconds': '1549',
#   'trip_miles': '16.49',
#   'pickup_community_area': '76',
#   'dropoff_community_area': '8',
#   'fare': '41.75',
#   'tips': '6.94',
#   'tolls': '0',
#   'extras': '4',
#   'trip_total': '53.19',
#   'payment_type': 'Mobile',
#   'company': 'City Service',
#   'pickup_centroid_latitude': '41.980264315',
#   'pickup_centroid_longitude': '-87.913624596',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.913624596, 41.9802643146]},
#   'dropoff_centroid_latitude': '41.899602111',
#   'dropoff_centroid_longitude': '-87.633308037',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6333080367, 41.899602111]}},
#  {'trip_id': 'd75394da287603a4a1fca69ad538e61cdc756f8f',
#   'taxi_id': 'a0a886ad03fbdf977af36c2495d1f737bb58e23484818c8d7dc01578af65642104024f22b6bddc7b22564e196e24e7fef1b158ad66bb70dac7491a6892d138bf',
#   'trip_start_timestamp': '2023-11-27T21:45:00.000',
#   'trip_end_timestamp': '2023-11-27T21:45:00.000',
#   'trip_seconds': '367',
#   'trip_miles': '0.88',
#   'pickup_community_area': '8',
#   'dropoff_community_area': '8',
#   'fare': '6',
#   'tips': '0',
#   'tolls': '0',
#   'extras': '1',
#   'trip_total': '7',
#   'payment_type': 'Cash',
#   'company': 'Flash Cab',
#   'pickup_centroid_latitude': '41.899602111',
#   'pickup_centroid_longitude': '-87.633308037',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6333080367, 41.899602111]},
#   'dropoff_centroid_latitude': '41.899602111',
#   'dropoff_centroid_longitude': '-87.633308037',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6333080367, 41.899602111]}},
#  {'trip_id': 'd5cd3b7f279d62aa4c4211d55139721135548a72',
#   'taxi_id': '2ac1345b1d51e156d379f3d68fbce527f896642a8464164299cd9511dcf73aabd4852709c0a32b4182e4b1f3a0917c09fc088b1fdbe2c06fa01ccd02f6a84fa3',
#   'trip_start_timestamp': '2023-11-27T21:45:00.000',
#   'trip_end_timestamp': '2023-11-27T21:45:00.000',
#   'trip_seconds': '0',
#   'trip_miles': '0',
#   'pickup_census_tract': '17031980000',
#   'dropoff_census_tract': '17031980000',
#   'pickup_community_area': '76',
#   'dropoff_community_area': '76',
#   'fare': '3.25',
#   'tips': '0',
#   'tolls': '0',
#   'extras': '0',
#   'trip_total': '3.25',
#   'payment_type': 'Cash',
#   'company': 'Taxi Affiliation Services',
#   'pickup_centroid_latitude': '41.97907082',
#   'pickup_centroid_longitude': '-87.903039661',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.9030396611, 41.9790708201]},
#   'dropoff_centroid_latitude': '41.97907082',
#   'dropoff_centroid_longitude': '-87.903039661',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.9030396611, 41.9790708201]}},
#  {'trip_id': 'd8587a15821f70ba38ba5df102b6c0cd0a8767a5',
#   'taxi_id': '519ec685026f0f617abc95e752338a4983798aee6bb05d6d31eb5b7470e2658b668c5ba9a4304c6e466f5dad3fa151a9637b712d8f3f228273a8bd29a5756881',
#   'trip_start_timestamp': '2023-11-27T21:45:00.000',
#   'trip_end_timestamp': '2023-11-27T22:00:00.000',
#   'trip_seconds': '1180',
#   'trip_miles': '17.63',
#   'pickup_census_tract': '17031980000',
#   'dropoff_census_tract': '17031081000',
#   'pickup_community_area': '76',
#   'dropoff_community_area': '8',
#   'fare': '43',
#   'tips': '10',
#   'tolls': '0',
#   'extras': '6.5',
#   'trip_total': '60',
#   'payment_type': 'Credit Card',
#   'company': 'Choice Taxi Association Inc',
#   'pickup_centroid_latitude': '41.97907082',
#   'pickup_centroid_longitude': '-87.903039661',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.9030396611, 41.9790708201]},
#   'dropoff_centroid_latitude': '41.900265687',
#   'dropoff_centroid_longitude': '-87.63210922',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6321092196, 41.9002656868]}},
#  {'trip_id': 'ccaa42b6532c052a222852b238f371a0c306d837',
#   'taxi_id': '72acb561bc3ff52febfb74f963b7e3a637c4a5de6f13607932913e3c2386875e135d8f81a10e72bae9c8839b88ade59b6d4d45b9b549ecf401e485d9650048fb',
#   'trip_start_timestamp': '2023-11-27T21:45:00.000',
#   'trip_end_timestamp': '2023-11-27T22:00:00.000',
#   'trip_seconds': '436',
#   'trip_miles': '0.95',
#   'pickup_census_tract': '17031081500',
#   'dropoff_census_tract': '17031081201',
#   'pickup_community_area': '8',
#   'dropoff_community_area': '8',
#   'fare': '6.75',
#   'tips': '0',
#   'tolls': '0',
#   'extras': '0',
#   'trip_total': '6.75',
#   'payment_type': 'Cash',
#   'company': '5 Star Taxi',
#   'pickup_centroid_latitude': '41.892507781',
#   'pickup_centroid_longitude': '-87.626214906',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6262149064, 41.8925077809]},
#   'dropoff_centroid_latitude': '41.899155613',
#   'dropoff_centroid_longitude': '-87.626210532',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6262105324, 41.8991556134]}},
#  {'trip_id': 'd0e932bd543dbeaf3e38751a3206186cfee1c9dd',
#   'taxi_id': 'ac631f0167353286bd820a3d29d38490cf7380d95b59d55a8e5136770c0faf611c90757ed6943a2c174e73d603d0bb20d33a4599166bf42e9e6c7c095349c956',
#   'trip_start_timestamp': '2023-11-27T21:45:00.000',
#   'trip_end_timestamp': '2023-11-27T21:45:00.000',
#   'trip_seconds': '587',
#   'trip_miles': '2.63',
#   'pickup_census_tract': '17031980000',
#   'dropoff_census_tract': '17031770700',
#   'pickup_community_area': '76',
#   'fare': '10.25',
#   'tips': '0',
#   'tolls': '0',
#   'extras': '5',
#   'trip_total': '15.75',
#   'payment_type': 'Credit Card',
#   'company': 'City Service',
#   'pickup_centroid_latitude': '41.97907082',
#   'pickup_centroid_longitude': '-87.903039661',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.9030396611, 41.9790708201]},
#   'dropoff_centroid_latitude': '41.982775009',
#   'dropoff_centroid_longitude': '-87.8773054',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.8773053996, 41.9827750091]}},
#  {'trip_id': 'ced4c8f9728909166d134b357328585ed5121adc',
#   'taxi_id': 'e637e1afe0dab0e2d04c635335602caf1045d43e3741c21eaea2a3507318a6a054a2ed9eb0a60db6bfd31b749a6fce3994639813662c25cf663ed4614cab4ec0',
#   'trip_start_timestamp': '2023-11-27T21:45:00.000',
#   'trip_end_timestamp': '2023-11-27T22:45:00.000',
#   'trip_seconds': '3840',
#   'trip_miles': '0.2',
#   'pickup_community_area': '3',
#   'dropoff_community_area': '1',
#   'fare': '13.75',
#   'tips': '0',
#   'tolls': '0',
#   'extras': '0',
#   'trip_total': '13.75',
#   'payment_type': 'Cash',
#   'company': 'Taxi Affiliation Services',
#   'pickup_centroid_latitude': '41.96581197',
#   'pickup_centroid_longitude': '-87.655878786',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6558787862, 41.96581197]},
#   'dropoff_centroid_latitude': '42.009622881',
#   'dropoff_centroid_longitude': '-87.670166857',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6701668569, 42.0096228806]}},
#  {'trip_id': 'c7e267d7e15af118ccc6589cca2ef957da542922',
#   'taxi_id': '842c6b006fcddcc1eb059c64c6129ed5edd0971d8943943075301b1845f3acafa4d74c84ac1a114a3c5e1534f081126e0012aaa85350643e7b5bdb97bbada08d',
#   'trip_start_timestamp': '2023-11-27T21:45:00.000',
#   'trip_end_timestamp': '2023-11-27T21:45:00.000',
#   'trip_seconds': '22',
#   'trip_miles': '0',
#   'pickup_census_tract': '17031320100',
#   'dropoff_census_tract': '17031320100',
#   'pickup_community_area': '32',
#   'dropoff_community_area': '32',
#   'fare': '0.15',
#   'tips': '0',
#   'tolls': '0',
#   'extras': '0',
#   'trip_total': '0.15',
#   'payment_type': 'Cash',
#   'company': 'Flash Cab',
#   'pickup_centroid_latitude': '41.884987192',
#   'pickup_centroid_longitude': '-87.620992913',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6209929134, 41.8849871918]},
#   'dropoff_centroid_latitude': '41.884987192',
#   'dropoff_centroid_longitude': '-87.620992913',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6209929134, 41.8849871918]}},
#  {'trip_id': 'c6ce50a40c21fa4b270490dd02ea6b5cc1781c56',
#   'taxi_id': 'c531f081cad817a366cbae2254ce7a3bb370394b3b0f1399dfc8781333c3565ca188035bbff4d1d7652181b79712c103d01ab168cb6ca2580f2da4b324cb00a5',
#   'trip_start_timestamp': '2023-11-27T21:45:00.000',
#   'trip_end_timestamp': '2023-11-27T22:45:00.000',
#   'trip_seconds': '3427',
#   'trip_miles': '13.28',
#   'pickup_community_area': '76',
#   'dropoff_community_area': '3',
#   'fare': '43.75',
#   'tips': '8.85',
#   'tolls': '0',
#   'extras': '0',
#   'trip_total': '53.1',
#   'payment_type': 'Credit Card',
#   'company': 'Flash Cab',
#   'pickup_centroid_latitude': '41.980264315',
#   'pickup_centroid_longitude': '-87.913624596',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.913624596, 41.9802643146]},
#   'dropoff_centroid_latitude': '41.96581197',
#   'dropoff_centroid_longitude': '-87.655878786',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6558787862, 41.96581197]}},
#  {'trip_id': 'cb51d44bb05f96e6f2f5e6c2258893af169ff196',
#   'taxi_id': '0083fcde0fb490b4ec424c63d1d750378f6ad11154d1d4a1cd5388b0b7d16c72eacf606c4d90cbdee388d2a99f3ed24d126ee948ba7c37da0af1d254b8b069cf',
#   'trip_start_timestamp': '2023-11-27T21:45:00.000',
#   'trip_end_timestamp': '2023-11-27T21:45:00.000',
#   'trip_seconds': '0',
#   'trip_miles': '0',
#   'pickup_census_tract': '17031081700',
#   'dropoff_census_tract': '17031081700',
#   'pickup_community_area': '8',
#   'dropoff_community_area': '8',
#   'fare': '3.25',
#   'tips': '0',
#   'tolls': '0',
#   'extras': '0',
#   'trip_total': '3.25',
#   'payment_type': 'Cash',
#   'company': 'Taxi Affiliation Services',
#   'pickup_centroid_latitude': '41.892042136',
#   'pickup_centroid_longitude': '-87.63186395',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6318639497, 41.8920421365]},
#   'dropoff_centroid_latitude': '41.892042136',
#   'dropoff_centroid_longitude': '-87.63186395',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6318639497, 41.8920421365]}},
#  {'trip_id': 'c9811d938fab26453c896d6a0ed2630d7bb4d5dc',
#   'taxi_id': '42bfc19863617733aaa5ef96de670e3307690921a42d3df9e13ff7a35fa621088d7656cf297d3bb44306fa4ebc03bc631afc3c050b0562dea4b0b833e85818d2',
#   'trip_start_timestamp': '2023-11-27T21:45:00.000',
#   'trip_end_timestamp': '2023-11-27T22:00:00.000',
#   'trip_seconds': '908',
#   'trip_miles': '3.19',
#   'pickup_community_area': '8',
#   'dropoff_community_area': '33',
#   'fare': '12.5',
#   'tips': '3.25',
#   'tolls': '0',
#   'extras': '0',
#   'trip_total': '16.25',
#   'payment_type': 'Credit Card',
#   'company': 'Sun Taxi',
#   'pickup_centroid_latitude': '41.899602111',
#   'pickup_centroid_longitude': '-87.633308037',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6333080367, 41.899602111]},
#   'dropoff_centroid_latitude': '41.857183858',
#   'dropoff_centroid_longitude': '-87.620334624',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6203346241, 41.8571838585]}},
#  {'trip_id': 'c5f0de30d9d5d60e0812d093cfce83a7d6b74391',
#   'taxi_id': '8ebf95dabfe8520c7decd46e691ca8811c875a4b842b3ab9e69d53c6ac4f508450b21067bcc4c0088e304fb2cab0e28cde60eceb2c770e3f76d6e6950b15f324',
#   'trip_start_timestamp': '2023-11-27T21:45:00.000',
#   'trip_end_timestamp': '2023-11-27T22:00:00.000',
#   'trip_seconds': '985',
#   'trip_miles': '7.7',
#   'pickup_community_area': '32',
#   'dropoff_community_area': '6',
#   'fare': '21',
#   'tips': '5.38',
#   'tolls': '0',
#   'extras': '0',
#   'trip_total': '26.88',
#   'payment_type': 'Credit Card',
#   'company': 'City Service',
#   'pickup_centroid_latitude': '41.878865584',
#   'pickup_centroid_longitude': '-87.625192142',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6251921424, 41.8788655841]},
#   'dropoff_centroid_latitude': '41.944226601',
#   'dropoff_centroid_longitude': '-87.655998182',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6559981815, 41.9442266014]}},
#  {'trip_id': 'c1a883cbd8cddf705eae23157d0c3303c95633ac',
#   'taxi_id': 'a0a886ad03fbdf977af36c2495d1f737bb58e23484818c8d7dc01578af65642104024f22b6bddc7b22564e196e24e7fef1b158ad66bb70dac7491a6892d138bf',
#   'trip_start_timestamp': '2023-11-27T21:45:00.000',
#   'trip_end_timestamp': '2023-11-27T22:00:00.000',
#   'trip_seconds': '424',
#   'trip_miles': '1.92',
#   'pickup_census_tract': '17031081300',
#   'dropoff_census_tract': '17031842200',
#   'pickup_community_area': '8',
#   'dropoff_community_area': '8',
#   'fare': '8',
#   'tips': '0',
#   'tolls': '0',
#   'extras': '1',
#   'trip_total': '9',
#   'payment_type': 'Cash',
#   'company': 'Flash Cab',
#   'pickup_centroid_latitude': '41.898331794',
#   'pickup_centroid_longitude': '-87.620762865',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6207628651, 41.8983317935]},
#   'dropoff_centroid_latitude': '41.904935302',
#   'dropoff_centroid_longitude': '-87.649907226',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6499072264, 41.9049353016]}},
#  {'trip_id': 'c60d99c7aa03b466de0dba409319357460afd644',
#   'taxi_id': '5a2d8508678f817213f775688e8a0dd949cc26dd393542b277a2ee908d605c4cbe49e70ba750da01112b6f87a0d69a6ec2eaa28729eea473b8d35dcb3657b6bc',
#   'trip_start_timestamp': '2023-11-27T21:45:00.000',
#   'trip_end_timestamp': '2023-11-27T22:15:00.000',
#   'trip_seconds': '1848',
#   'trip_miles': '21.36',
#   'pickup_community_area': '1',
#   'dropoff_community_area': '44',
#   'fare': '59.91',
#   'tips': '0',
#   'tolls': '0',
#   'extras': '0',
#   'trip_total': '59.91',
#   'payment_type': 'Cash',
#   'company': 'Flash Cab',
#   'pickup_centroid_latitude': '42.009622881',
#   'pickup_centroid_longitude': '-87.670166857',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6701668569, 42.0096228806]},
#   'dropoff_centroid_latitude': '41.740205756',
#   'dropoff_centroid_longitude': '-87.615969523',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6159695226, 41.7402057565]}},
#  ...]
